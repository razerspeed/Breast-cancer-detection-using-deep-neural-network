# %%
import numpy as np
import matplotlib.pyplot as plt
import os
from PIL import Image
import glob
import random
import cv2
from random import shuffle
from PIL import Image, ImageEnhance
from skimage import measure

# %%
for im in os.listdir('rle_image_dataset_1/'):
    print(im[:-4])
    break
# Out:
# A00_01

# %%
file2write=[]
for im in os.listdir('rle_image_dataset_1/'):
    raw = Image.open(f'rle_image_dataset_1/{im}')
    raw=np.array(raw)
    raw=np.array(raw)
    label_mask = measure.label(raw)

    regions = measure.regionprops(label_mask)
#     fig, ax = plt.subplots()
#     ax.imshow(raw, cmap=plt.cm.gray)

    for props in regions:

        minr, minc, maxr, maxc = props.bbox
    #     bx = (minc, maxc, maxc, minc, minc)
    #     by = (minr, minr, maxr, maxr, minr)
    #     ax.plot(bx, by, '-b', linewidth=1)
        file2write.append(f"dataset_1/{im[:-4]}.bmp,{minr},{minc},{maxr},{maxc},mitosis \n")
#     break
    # ax.axis((0, 600, 600, 0))

# %%
file2write
# Out:
# ['dataset_1/A00_01.bmp,22,1630,53,1698,mitosis \n',
#  'dataset_1/A00_01.bmp,82,1418,108,1446,mitosis \n',
#  'dataset_1/A00_01.bmp,186,1391,223,1439,mitosis \n',
#  'dataset_1/A00_01.bmp,299,595,330,625,mitosis \n',
#  'dataset_1/A00_01.bmp,1896,1557,1930,1589,mitosis \n',
#  'dataset_1/A00_02.bmp,175,1239,212,1280,mitosis \n',
#  'dataset_1/A00_02.bmp,188,357,225,389,mitosis \n',
#  'dataset_1/A00_03.bmp,239,144,269,168,mitosis \n',
#  'dataset_1/A00_03.bmp,1240,338,1294,413,mitosis \n',
#  'dataset_1/A00_04.bmp,808,1138,829,1158,mitosis \n',
#  'dataset_1/A00_04.bmp,855,1131,873,1152,mitosis \n',
#  'dataset_1/A00_04.bmp,1105,376,1138,394,mitosis \n',
#  'dataset_1/A00_04.bmp,1115,440,1148,464,mitosis \n',
#  'dataset_1/A00_04.bmp,1418,1685,1476,1722,mitosis \n',
#  'dataset_1/A00_05.bmp,1727,1068,1783,1100,mitosis \n',
#  'dataset_1/A00_06.bmp,360,1637,389,1675,mitosis \n',
#  'dataset_1/A00_06.bmp,1376,1195,1402,1229,mitosis \n',
# ...

# %%
with open('simple_data.txt', 'w') as f:

    f.writelines(file2write)
